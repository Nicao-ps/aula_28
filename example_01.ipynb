# %%
# 1º Step: Obtain data from PATH_DATA and load it into a DataFrame.

import pandas as pd 
import numpy as np

PATH_DATA = 'https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv'

try:
    df_robs = pd.read_csv(PATH_DATA, sep=';', encoding='iso-8859-1')
    print(f'Data obtained from PATH_DATA sucessfully. DataFrame loaded with {df_robs.shape[0]} rows and {df_robs.shape[1]} columns.')

except Exception as e:
    print(f'Error while obtaining data from PATH_DATA. {e}')
# Out:
# Data obtained from PATH_DATA sucessfully. DataFrame loaded with 36355 rows and 63 columns.

# %%
#2º Step: Dellimiting and groupingby DataFrame.

try:
    data_correction = df_robs['regiao'].str.startswith('Grande Niter', na=False)
    df_robs.loc[data_correction, 'regiao'] = 'Grande Niterói'
    df_robs = df_robs[['cisp', 'regiao', 'munic', 'roubo_veiculo']]
    df_robs_gb = df_robs.groupby(['cisp', 'regiao', 'munic']).sum(['roubo_veiculo']).reset_index()
    df_robs_gb_filtered = df_robs_gb.sort_values(by='munic', ascending=True)
    print(f'DataFrame grouped by by cisp, regiao, and munic with {df_robs_gb_filtered.shape[0]} rows and {df_robs_gb_filtered.shape[1]} columns.')

except Exception as e:
    print(f'Error while dellimiting and groupingby DataFrame. {e}')
# Out:
# DataFrame grouped by by cisp, regiao, and munic with 146 rows and 4 columns.

# %%
#3º Step: Write all variables from a selected column into a archive .txt.

try:
    with open('municipalities.txt', 'w', encoding='utf-8-sig') as municipalities:
        municipalities.write('Municipalities:\n\n')
        municipalities.write('\n'.join(df_robs_gb_filtered['munic'].unique()))
    print('Municipalities written to municipalities.txt successfully.')

except Exception as e:
    print(f'Error while trying to write municipalities to municipalities.txt. {e}')
# Out:
# Municipalities written to municipalities.txt successfully.

# %%
# 4º Step: Write all variables from dataframe into a archive .txt.

try:
    with open('variables.txt', 'w', encoding='iso-8859-1') as titles:
        titles.write('Variables:\n\n')
        titles.write('\n'.join(df_robs_gb_filtered.head(0)))
    print('Variables written to variables.txt successfully.')

except Exception as e:
    print(f'Error while trying to write variables to variables.txt. {e}')
# Out:
# Variables written to variables.txt successfully.

# %%
# 5º Step: Obtain measures of central tendency.

try:
    array_robs = np.array(df_robs_gb_filtered['roubo_veiculo'])
    total = np.sum(array_robs)
    mean = np.mean(array_robs)
    median = np.median(array_robs)
    min = np.min(array_robs)
    max = np.max(array_robs)

    print('Measures of central tendency:'+'\n')
    print(f'Total: {total}')
    print(f'Mean: {mean}')
    print(f'Median: {median}')
    print(f'Min: {min}')
    print(f'Max: {max}')

except Exception as e:
    print(f'Error while obtaining measures of central tendency. {e}')
# Out:
# Measures of central tendency:
#
# Total: 697681.00
# Mean: 3751.0
# Median: 307.0
# Min: 0.0
# Max: 36274.0

# %%
# 6º Step: Obtain measures of dispersion.

try:
    std_dev = np.std(array_robs)
    var = np.var(array_robs)
    q1 = np.percentile(array_robs, 25)
    q3 = np.percentile(array_robs, 75)
    iqr = q3 - q1

    print('\nMeasures of dispersion:'+'\n')
    print(f'Standard Deviation: {std_dev:.2f}')
    print(f'Variance: {var:.2f}')
    print(f'Q1: {q1:.2f}')
    print(f'Q3: {q3:.2f}')
    print(f'IQR: {iqr:.2f}')

except Exception as e:
    print(f'Error while obtaining measures of dispersion. {e}')
# Out:
# Measures of dispersion:
#
# Standard Deviation: 6793.85
# Variance: 46156448.18
# Q1: 29.25
# Q3: 3883.25
# IQR: 3854.00

# %%
# 7º Step: Obtain mayors and minors.

try:
    # Gerar um dataframe com os maiores
    # Copy() quando preciar alterar um dataframe já filtrado
    df_rob_mayors =  df_robs_gb_filtered[df_robs_gb_filtered['roubo_veiculo'] > q3].copy()
    df_rob_mayors['flag'] = 'mayors'
    # print(df_maiores)

    # Gerar um dataframe com os menores
    df_robs_minors = df_robs_gb_filtered[df_robs_gb_filtered['roubo_veiculo'] < q1].copy()
    df_robs_minors['flag'] = 'minors'
    # print(df_menores)

    # Concatenar os dois dataframes
    df_roubos_flags = pd.concat([df_rob_mayors, df_robs_minors], ignore_index=True)

    display(df_roubos_flags)
except Exception as e:
    print(f'Error while obtaining mayors and minors: {e}')
# Out:
#     cisp              regiao  \
# 0     54  Baixada Fluminense
# 1     60  Baixada Fluminense
# 2     59  Baixada Fluminense
# 3     62  Baixada Fluminense
# 4     71            Interior
# 5     50  Baixada Fluminense
# 6     53  Baixada Fluminense
# 7     57  Baixada Fluminense
# 8     77      Grande Niterói
# 9     78      Grande Niterói
# 10    56  Baixada Fluminense
# 11    52  Baixada Fluminense
# 12    58  Baixada Fluminense
# 13    29             Capital
# 14    28             Capital
# 15    27             Capital
# 16    26             Capital
# 17    25             Capital
# 18    24             Capital
# 19    23             Capital
# 20    22             Capital
# 21    21             Capital
# 22    20             Capital
# 23    19             Capital
# 24    18             Capital
# 25    17             Capital
# 26    16             Capital
# 27     9             Capital
# 28     6             Capital
# 29    30             Capital
# 30    31             Capital
# 31    44             Capital
# 32    41             Capital
# 33    40             Capital
# 34    39             Capital
# 35    38             Capital
# 36    37             Capital
# 37    35             Capital
# 38    34             Capital
# 39    33             Capital
# 40    32             Capital
# 41    36             Capital
# 42    73      Grande Niterói
# 43    72      Grande Niterói
# 44    74      Grande Niterói
# 45    75      Grande Niterói
# 46    64  Baixada Fluminense
# 47   158            Interior
# 48   144            Interior
# 49   142            Interior
# 50   148            Interior
# 51   154            Interior
# 52   152            Interior
# 53    98            Interior
# 54   135            Interior
# 55   143            Interior
# 56   138            Interior
# 57    97            Interior
# 58   137            Interior
# 59   140            Interior
# 60   139            Interior
# 61    92            Interior
# 62    11             Capital
# 63    45             Capital
# 64   104            Interior
# 65   155            Interior
# 66   157            Interior
#
#                                                munic  roubo_veiculo    flag
# 0                                       Belford Roxo          23967  mayors
# 1                                    Duque de Caxias          19513  mayors
# 2                                    Duque de Caxias          36274  mayors
# 3                                    Duque de Caxias           8667  mayors
# 4                                           Itaboraí           6169  mayors
# 5                                            Itaguaí           3999  mayors
# 6                                           Mesquita           8190  mayors
# 7                                          Nilópolis          12257  mayors
# 8                                            Niterói           4122  mayors
# 9                                            Niterói           8401  mayors
# 10                                       Nova Iguaçu          11522  mayors
# 11                                       Nova Iguaçu          15023  mayors
# 12                                       Nova Iguaçu          15657  mayors
# 13                                    Rio de Janeiro          15532  mayors
# 14                                    Rio de Janeiro          10771  mayors
# 15                                    Rio de Janeiro          26905  mayors
# 16                                    Rio de Janeiro           7518  mayors
# 17                                    Rio de Janeiro          10792  mayors
# 18                                    Rio de Janeiro          11418  mayors
# 19                                    Rio de Janeiro          10612  mayors
# 20                                    Rio de Janeiro          14858  mayors
# 21                                    Rio de Janeiro          19279  mayors
# 22                                    Rio de Janeiro           8911  mayors
# 23                                    Rio de Janeiro           6680  mayors
# 24                                    Rio de Janeiro           7087  mayors
# 25                                    Rio de Janeiro           7505  mayors
# 26                                    Rio de Janeiro           5799  mayors
# 27                                    Rio de Janeiro           4614  mayors
# 28                                    Rio de Janeiro           4516  mayors
# 29                                    Rio de Janeiro          12360  mayors
# 30                                    Rio de Janeiro          14428  mayors
# 31                                    Rio de Janeiro          14285  mayors
# 32                                    Rio de Janeiro           6268  mayors
# 33                                    Rio de Janeiro          18534  mayors
# 34                                    Rio de Janeiro          28264  mayors
# 35                                    Rio de Janeiro          19332  mayors
# 36                                    Rio de Janeiro           7321  mayors
# 37                                    Rio de Janeiro          18789  mayors
# 38                                    Rio de Janeiro          27001  mayors
# 39                                    Rio de Janeiro          17592  mayors
# 40                                    Rio de Janeiro           7940  mayors
# 41                                    Rio de Janeiro           5077  mayors
# 42                                       São Gonçalo          13456  mayors
# 43                                       São Gonçalo          13594  mayors
# 44                                       São Gonçalo          17461  mayors
# 45                                       São Gonçalo           9745  mayors
# 46                                São João de Meriti          31386  mayors
# 47                                        Bom Jardim             21  minors
# 48                           Bom Jesus de Itabapoana             19  minors
# 49                                           Cambuci              9  minors
# 50                            Cardoso Moreira;Italva             26  minors
# 51                                   Cordeiro;Macuco             21  minors
# 52                                       Duas Barras             13  minors
# 53                       Engenheiro Paulo de Frontin             17  minors
# 54                                          Itaocara             24  minors
# 55  Itaperuna;São José de Ubá;Cardoso Moreira;Italva             25  minors
# 56                                    Laje do Muriaé              2  minors
# 57                                            Mendes             23  minors
# 58                                          Miracema              6  minors
# 59                              Natividade;Varre-Sai              7  minors
# 60                                       Porciúncula              7  minors
# 61                                    Rio das Flores              8  minors
# 62                                    Rio de Janeiro             16  minors
# 63                                    Rio de Janeiro             27  minors
# 64                     São José do Vale do Rio Preto             20  minors
# 65                             São Sebastião do Alto             29  minors
# 66                                 Trajano de Morais             20  minors
